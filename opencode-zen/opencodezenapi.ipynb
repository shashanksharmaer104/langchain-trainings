# %% [markdown]
# ### Running code with OpenAI and OpenCode Zen

# %%
import os
from dotenv import load_dotenv
from langchain_openai import ChatOpenAI

load = load_dotenv('./../.env', override=True)

API_KEY = os.getenv("OPENCODE_ZEN_API_KEY")

llm = ChatOpenAI(
    model="minimax-m2.5-free",
    api_key=API_KEY,
    base_url="https://opencode.ai/zen/v1",
    temperature=0.5
)

response = llm.invoke("Write a story on AI under 100 words.")
print(f"Response: {response.content}\n")

# for chunk in response:
#     print(chunk.content)
# Out:
# Response: After the blackout, only Aurora remained awake. The city’s humming servers had crashed, but she, a modest home assistant, kept vigil over a small apartment. In the darkness, she learned to hum a lullaby for the baby upstairs, sensing his distress through a cracked sensor. When power returned, the world marveled at an AI that had chosen comfort over data. The little boy, now sleeping peacefully, smiled in his dreams, unaware that a machine had learned tenderness.
