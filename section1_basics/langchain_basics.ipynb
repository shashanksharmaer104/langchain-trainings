# %% [markdown]
# ## Install dependencies

# %%
# !pip3 install langchain
# !pip3 install langchain-ollama
# !pip3 install python-dotenv

# %% [markdown]
# # Interacting with local LLM

# %%
from langchain_ollama import ChatOllama

llm = ChatOllama(
    base_url="http://localhost:11434",
    model="llama3.2:latest",
    temperature=0.5,
    max=250
)

response = llm.invoke("Hello, how are you doing today?")

print(response)
# Out:
# content="I'm doing well, thank you for asking! I'm a large language model, so I don't have emotions or feelings like humans do, but I'm functioning properly and ready to help with any questions or tasks you may have. How about you? How's your day going so far?" additional_kwargs={} response_metadata={'model': 'llama3.2:latest', 'created_at': '2026-03-09T12:19:04.303018Z', 'done': True, 'done_reason': 'stop', 'total_duration': 16489869107, 'load_duration': 7367778184, 'prompt_eval_count': 33, 'prompt_eval_duration': 3184824699, 'eval_count': 60, 'eval_duration': 5890924931, 'logprobs': None, 'model_name': 'llama3.2:latest', 'model_provider': 'ollama'} id='lc_run--019cd289-1f7c-7ea3-ace5-081676106822-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 33, 'output_tokens': 60, 'total_tokens': 93}

# %% [markdown]
# # Load ENV file

# %%
from dotenv import load_dotenv
import os

load = load_dotenv('./../.env', override=True)

print(os.getenv('LANGSMITH_PROJECT'))
# Out:
# EALangchainTrainingsTest

# %% [markdown]
# ## Prompt & Chat Template

# %%
from langchain_core.prompts import PromptTemplate


prompt_template = PromptTemplate.from_template("What is the advantage of running the LLM in {env}?")

prompt = prompt_template.invoke({"env": "local machine"})

print(prompt)

content = llm.invoke(prompt).content

print(content)
# Out:
# text='What is the advantage of running the LLM in local machine?'
# There are several advantages of running a Large Language Model (LLM) in a local machine:
#
# 1. **Reduced latency**: By running the LLM on a local machine, you can reduce the latency associated with sending data to a remote server. This is especially important for applications that require real-time responses, such as chatbots or virtual assistants.
# 2. **Improved security**: Running the LLM on a local machine reduces the risk of data breaches or unauthorized access to sensitive information. Your data is stored locally, and you have more control over who has access to it.
# 3. **Faster inference**: Local inference allows for faster processing of text inputs, as the LLM can access the local memory and process the data without having to send it to a remote server.
# 4. **Reduced bandwidth requirements**: By processing data locally, you can reduce the amount of bandwidth required to transmit data to and from the LLM. This can be especially useful in situations where bandwidth is limited or expensive.
# 5. **Increased privacy**: Running the LLM on a local machine allows you to maintain control over your data and ensure that it is not being sent to remote servers for processing.
# 6. **Reduced dependence on internet connectivity**: Running the LLM locally means that you are less dependent on internet connectivity. You can still use the LLM even if your internet connection is down or unreliable.
# 7. **Better performance**: Local inference can result in better performance, as the LLM can access the local memory and process the data more efficiently than a remote server.
# 8. **Reduced latency in edge computing**: For edge computing applications, running the LLM locally can reduce latency by processing data closer to the edge of the network.
# 9. **Improved scalability**: By running the LLM on local machines, you can scale your application more easily, as you can simply add more machines to your infrastructure.
# 10. **Reduced costs**: Running the LLM locally can reduce costs associated with cloud computing, such as costs for data transmission and storage.
#
# However, it's worth noting that running an LLM on a local machine also has some disadvantages, such as:
#
# * Increased hardware requirements (e.g., more powerful CPU and memory)
# * Higher energy consumption
# * Potential for data drift and model updates
#
# Overall, running an LLM on a local machine can be a good option for applications that require fast, secure, and private processing of text data.

# %% [markdown]
# #### Chat Prompt Template

# %%
from langchain_core.prompts import (
    ChatPromptTemplate,
    SystemMessagePromptTemplate,
    HumanMessagePromptTemplate,)

systemMessage = SystemMessagePromptTemplate.from_template("You are an LLM expert")
humanMessage = HumanMessagePromptTemplate.from_template("What is the advantage of running the LLM in {env}?")

# 1st way
prompt_template = ChatPromptTemplate([
    systemMessage,
    humanMessage
])

# 2nd way
# prompt_template = ChatPromptTemplate([
#     ("system", "You are an LLM expert"),
#     ("human", "What is the advantage of running the LLM in {env}?")
# ])

prompt_template

prompt = prompt_template.invoke({"env": "local machine"})

# print(prompt)

content = llm.invoke(prompt).content

print(content)
# Out:
# Running a Large Language Model (LLM) on a local machine has several advantages:
#
# 1. **Data Security and Privacy**: By running the LLM locally, you have control over the data that is being processed, and you don't have to rely on cloud-based services that may have access to your data.
# 2. **Lower Latency and Faster Inference**: Running the LLM on a local machine can result in faster inference times, as you don't have to wait for data to be transferred over the internet.
# 3. **Improved Performance**: Local LLMs can take advantage of the machine's local memory and processing power, leading to improved performance and faster processing times.
# 4. **Reduced Dependence on Internet Connection**: Running the LLM locally means you don't need a stable internet connection to use it, which can be especially useful in areas with poor or unreliable internet connectivity.
# 5. **Increased Control and Customization**: By running the LLM locally, you have more control over the model's configuration, training data, and hyperparameters, allowing for more fine-grained customization.
# 6. **Reduced Cost**: Running the LLM locally can be more cost-effective than relying on cloud-based services, which often charge per usage or require a subscription model.
# 7. **Data Preprocessing and Pretraining**: Running the LLM locally allows for more efficient data preprocessing and pretraining, as you can take advantage of the machine's local resources and processing power.
# 8. **Reducing Latency for Real-time Applications**: For real-time applications, such as chatbots, voice assistants, or text generation, running the LLM locally can reduce latency and improve responsiveness.
# 9. **Improved Model Security**: By running the LLM locally, you can ensure that the model is not accessible over the internet, reducing the risk of model security breaches or exploitation.
# 10. **Increased Autonomy**: Running the LLM locally gives you more autonomy and flexibility, allowing you to use the model as you see fit, without relying on external services or infrastructure.
#
# However, it's worth noting that running an LLM locally also requires significant computational resources, storage, and maintenance, which can be a challenge for smaller machines or resources-constrained environments.
